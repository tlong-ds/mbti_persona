# %%
import pandas as pd

# %%
questions = pd.read_csv('qsets.tsv', sep = '\t')

# %%
questions
# Out:
#                                              question dimension
# 0                     You regularly make new friends.       E/I
# 1   Complex and novel ideas excite you more than s...       S/N
# 2   You usually find factual arguments more persua...       T/F
# 3   Your living and working spaces are clean and o...       J/P
# 4   You usually stay calm, even under a lot of pre...       J/P
# 5   You find the idea of networking or promoting y...       E/I
# 6   You prioritize and plan tasks effectively, oft...       J/P
# 7   Numbers and data are more persuasive to you th...       T/F
# 8   You like to use organizing tools like schedule...       J/P
# 9   Even a small mistake can cause you to doubt yo...       J/P
# 10  You feel comfortable just walking up to someon...       E/I
# 11  You are not too interested in discussions abou...       S/N
# 12  You prioritize facts over people's feelings wh...       T/F
# 13  You often allow the day to unfold without any ...       J/P
# ...

# %%
current = 0
questions.iloc[current]['question']
# Out:
# 'Complex and novel ideas excite you more than simple and straightforward ones.'
